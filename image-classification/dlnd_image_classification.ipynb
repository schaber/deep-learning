# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [02:39, 1.07MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 12
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 12:
# Image - Min Value: 2 Max Value: 251
# Image - Shape: (32, 32, 3)
# Label - Label Id: 7 Name: horse

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    min_val = np.min(x)
    max_val = np.max(x)
    
    return (np.array(x) - min_val)/(max_val - min_val)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
# The hint says "don't reinvent the wheel, so I'm using scikit-learn as described 
    #  in the Intro to TensorFlow module of the DLND.

from sklearn import preprocessing
lb = preprocessing.LabelBinarizer()
lb.fit(range(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    global lb
    
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %% [markdown]
# How to concatenate tuples:

# %%
image_shape = (1,2,3)
print((None,)+image_shape)
# Out:
# (None, 1, 2, 3)

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=((None,) + tuple(image_shape)), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.int32, shape=(None,n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #print(x_tensor.shape)
    # Weight and bias
    #print(conv_ksize)
    weight = tf.Variable(tf.truncated_normal(
        conv_ksize + (int(x_tensor.shape[-1]), conv_num_outputs), stddev=0.1))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    # Convolution and ReLU
    conv = tf.nn.conv2d(x_tensor, weight, (1,)+conv_strides+(1,), padding='SAME')
    conv = tf.nn.relu(tf.nn.bias_add(conv, bias))
    # Apply Max Pooling
    pooled = tf.nn.max_pool(conv, 
                            ksize  =(1,)+pool_ksize  +(1,), 
                            strides=(1,)+pool_strides+(1,),
                            padding='SAME')
    return pooled 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [-1, np.product(shape[1:])])

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    print(shape)
    # Weight and bias
    weight = tf.Variable(tf.truncated_normal(
        (shape[1], num_outputs), stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    out = tf.nn.bias_add(tf.matmul(x_tensor, weight), bias)
    return tf.nn.relu(out)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# [None, 128]
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    shape = x_tensor.get_shape().as_list()
    # Weight and bias
    weight = tf.Variable(tf.truncated_normal(
        (shape[1], num_outputs), stddev=0.1))
    bias = tf.Variable(tf.zeros(num_outputs))
    return tf.nn.bias_add(tf.matmul(x_tensor, weight), bias)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)    
    net1 = conv2d_maxpool(x, 40, (3,3), (1,1), (2,2), (1,1))
    net2 = conv2d_maxpool(net1, 80, (4,4), (1,1), (2,2), (2,2))
    net3 = conv2d_maxpool(net2, 120, (5,5), (2,2), (2,2), (2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    net1 = flatten(net1)
    net2 = flatten(net2)
    net3 = flatten(net3)

    #net = net1
    #net = tf.concat([net1, net2], 1) #inception
    net = tf.concat([net1, net2, net3], 1) #inception
    net = tf.nn.dropout(net, keep_prob)
    
    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    net = fully_conn(net, 160)
    net = tf.nn.dropout(net, keep_prob)
    net = fully_conn(net, 80)
    net = tf.nn.dropout(net, keep_prob)
    net = fully_conn(net, 40)
    net = tf.nn.dropout(net, keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(net, 10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# [None, 63360]
# [None, 160]
# [None, 80]
# [None, 63360]
# [None, 160]
# [None, 80]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function 
    # Based on code from lesson on Convolutional Networks, part 30. Convolutional Network in TensorFlow.
    #print(keep_probability)
    #print('feature_batch:')
    #print(feature_batch)
    #print('label_batch:')
    #print(label_batch)
    
    session.run(optimizer, feed_dict={
            x: feature_batch,
            y: label_batch,
            keep_prob: keep_probability})
    
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    # Calculate batch loss and accuracy
    # Based on code from lesson on Convolutional Networks, part 30. Convolutional Network in TensorFlow.
    loss = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.})
    valid_acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.})

    print('loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
        loss,
        valid_acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from datetime import datetime
start_time = datetime.now()

print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
        print('Train time per epoch = ' + str((datetime.now() - start_time)/(epoch+1)) + ' s')
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss:     2.2768 Validation Accuracy: 0.177400
# Train time per epoch = 0:01:50.542138 s
# Epoch  2, CIFAR-10 Batch 1:  loss:     2.2025 Validation Accuracy: 0.238600
# Train time per epoch = 0:01:47.247162 s
# Epoch  3, CIFAR-10 Batch 1:  loss:     2.0664 Validation Accuracy: 0.269800
# Train time per epoch = 0:01:45.783907 s
# Epoch  4, CIFAR-10 Batch 1:  loss:     1.9987 Validation Accuracy: 0.295200
# Train time per epoch = 0:01:45.376517 s
# Epoch  5, CIFAR-10 Batch 1:  loss:     1.9436 Validation Accuracy: 0.286400
# Train time per epoch = 0:01:44.629316 s
# Epoch  6, CIFAR-10 Batch 1:  loss:     1.7990 Validation Accuracy: 0.340200
# Train time per epoch = 0:01:44.067088 s
# Epoch  7, CIFAR-10 Batch 1:  loss:     1.7691 Validation Accuracy: 0.351800
# Train time per epoch = 0:01:44.141200 s
# Epoch  8, CIFAR-10 Batch 1:  loss:     1.7997 Validation Accuracy: 0.351800
# Train time per epoch = 0:01:44.109314 s
# Epoch  9, CIFAR-10 Batch 1:  loss:     1.6286 Validation Accuracy: 0.370800
# Train time per epoch = 0:01:44.294041 s
# Epoch 10, CIFAR-10 Batch 1:  loss:     1.5579 Validation Accuracy: 0.396800
# Train time per epoch = 0:01:44.547873 s
# Epoch 11, CIFAR-10 Batch 1:  loss:     1.5190 Validation Accuracy: 0.402200
# Train time per epoch = 0:01:44.688566 s
# Epoch 12, CIFAR-10 Batch 1:  loss:     1.4873 Validation Accuracy: 0.404200
# Train time per epoch = 0:01:44.712648 s
# Epoch 13, CIFAR-10 Batch 1:  loss:     1.4072 Validation Accuracy: 0.413800
# Train time per epoch = 0:01:44.703413 s
# Epoch 14, CIFAR-10 Batch 1:  loss:     1.3472 Validation Accuracy: 0.423000
# Train time per epoch = 0:01:44.816722 s
# Epoch 15, CIFAR-10 Batch 1:  loss:     1.3555 Validation Accuracy: 0.424000
# Train time per epoch = 0:01:44.776406 s
# Epoch 16, CIFAR-10 Batch 1:  loss:     1.2998 Validation Accuracy: 0.446600
# Train time per epoch = 0:01:44.820567 s
# Epoch 17, CIFAR-10 Batch 1:  loss:     1.2374 Validation Accuracy: 0.438000
# Train time per epoch = 0:01:44.750167 s
# Epoch 18, CIFAR-10 Batch 1:  loss:     1.1664 Validation Accuracy: 0.466200
# Train time per epoch = 0:01:44.728958 s
# Epoch 19, CIFAR-10 Batch 1:  loss:     1.1615 Validation Accuracy: 0.453000
# Train time per epoch = 0:01:44.931168 s
# Epoch 20, CIFAR-10 Batch 1:  loss:     1.0994 Validation Accuracy: 0.451600
# Train time per epoch = 0:01:45.035482 s
# Epoch 21, CIFAR-10 Batch 1:  loss:     1.0597 Validation Accuracy: 0.480400
# Train time per epoch = 0:01:45.214788 s
# Epoch 22, CIFAR-10 Batch 1:  loss:     1.0140 Validation Accuracy: 0.484000
# Train time per epoch = 0:01:45.225573 s
# Epoch 23, CIFAR-10 Batch 1:  loss:     0.9589 Validation Accuracy: 0.501800
# Train time per epoch = 0:01:45.451530 s
# Epoch 24, CIFAR-10 Batch 1:  loss:     0.9070 Validation Accuracy: 0.495600
# Train time per epoch = 0:01:45.580193 s
# Epoch 25, CIFAR-10 Batch 1:  loss:     0.8804 Validation Accuracy: 0.482600
# Train time per epoch = 0:01:45.644173 s
# Epoch 26, CIFAR-10 Batch 1:  loss:     0.8488 Validation Accuracy: 0.506200
# Train time per epoch = 0:01:45.544416 s
# Epoch 27, CIFAR-10 Batch 1:  loss:     0.7868 Validation Accuracy: 0.511000
# Train time per epoch = 0:01:45.589603 s
# Epoch 28, CIFAR-10 Batch 1:  loss:     0.8129 Validation Accuracy: 0.505200
# Epoch 25, CIFAR-10 Batch 3:  loss:  2939.8311 Validation Accuracy: 0.508200
# Epoch 25, CIFAR-10 Batch 4:  loss:  2030.1399 Validation Accuracy: 0.504800
# Epoch 25, CIFAR-10 Batch 5:  loss:  2425.7407 Validation Accuracy: 0.510400
# Epoch 26, CIFAR-10 Batch 1:  loss:  2664.9180 Validation Accuracy: 0.505400
# Epoch 26, CIFAR-10 Batch 2:  loss:  2084.6743 Validation Accuracy: 0.489600
# Epoch 26, CIFAR-10 Batch 3:  loss:  2330.1453 Validation Accuracy: 0.499800
# Epoch 26, CIFAR-10 Batch 4:  loss:  1578.0856 Validation Accuracy: 0.505200
# Epoch 26, CIFAR-10 Batch 5:  loss:  2244.6643 Validation Accuracy: 0.498400
# Epoch 27, CIFAR-10 Batch 1:  loss:  2367.3433 Validation Accuracy: 0.487000
# Epoch 27, CIFAR-10 Batch 2:  loss:  1932.2375 Validation Accuracy: 0.505400
# Epoch 27, CIFAR-10 Batch 3:  loss:  1996.4987 Validation Accuracy: 0.508400
# Epoch 27, CIFAR-10 Batch 4:  loss:  1135.3164 Validation Accuracy: 0.504400
# Epoch 27, CIFAR-10 Batch 5:  loss:  1787.1113 Validation Accuracy: 0.505200
# Epoch 28, CIFAR-10 Batch 1:  loss:  2132.2371 Validation Accuracy: 0.480400
# Epoch 28, CIFAR-10 Batch 2:  loss:  1542.6678 Validation Accuracy: 0.486200
# Epoch 28, CIFAR-10 Batch 3:  loss:  1792.1777 Validation Accuracy: 0.486000
# Epoch 28, CIFAR-10 Batch 4:  loss:  1140.3102 Validation Accuracy: 0.488600
# Epoch 28, CIFAR-10 Batch 5:  loss:  1301.3262 Validation Accuracy: 0.496000
# Epoch 29, CIFAR-10 Batch 1:  loss:  1682.1106 Validation Accuracy: 0.481200
# Epoch 29, CIFAR-10 Batch 2:  loss:  1285.1123 Validation Accuracy: 0.474800
# Epoch 29, CIFAR-10 Batch 3:  loss:  1447.1348 Validation Accuracy: 0.464200
# Epoch 29, CIFAR-10 Batch 4:  loss:   786.9825 Validation Accuracy: 0.482600
# Epoch 29, CIFAR-10 Batch 5:  loss:  1043.9299 Validation Accuracy: 0.484800
# Epoch 30, CIFAR-10 Batch 1:  loss:  1434.7610 Validation Accuracy: 0.482200
# Epoch 30, CIFAR-10 Batch 2:  loss:   992.8584 Validation Accuracy: 0.475800
# Epoch 30, CIFAR-10 Batch 3:  loss:  1087.5557 Validation Accuracy: 0.469200
# Epoch 30, CIFAR-10 Batch 4:  loss:   705.2151 Validation Accuracy: 0.479400
# Epoch 30, CIFAR-10 Batch 5:  loss:   815.7835 Validation Accuracy: 0.469400
# Epoch 31, CIFAR-10 Batch 1:  loss:  1222.1995 Validation Accuracy: 0.472000
# Epoch 31, CIFAR-10 Batch 2:  loss:   876.5959 Validation Accuracy: 0.469000
# Epoch 31, CIFAR-10 Batch 3:  loss:   772.3217 Validation Accuracy: 0.464600
# Epoch 31, CIFAR-10 Batch 4:  loss:   588.8029 Validation Accuracy: 0.467200
# Epoch 31, CIFAR-10 Batch 5:  loss:   651.0914 Validation Accuracy: 0.462400
# Epoch 32, CIFAR-10 Batch 1:  loss:   942.4629 Validation Accuracy: 0.451800
# Epoch 32, CIFAR-10 Batch 2:  loss:   635.1030 Validation Accuracy: 0.455000
# Epoch 32, CIFAR-10 Batch 3:  loss:   524.4420 Validation Accuracy: 0.452200
# Epoch 32, CIFAR-10 Batch 4:  loss:   441.8265 Validation Accuracy: 0.460600
# Epoch 32, CIFAR-10 Batch 5:  loss:   472.3156 Validation Accuracy: 0.450600
# Epoch 33, CIFAR-10 Batch 1:  loss:   752.7959 Validation Accuracy: 0.448600
# Epoch 33, CIFAR-10 Batch 2:  loss:   465.3748 Validation Accuracy: 0.431000
# Epoch 33, CIFAR-10 Batch 3:  loss:   309.5116 Validation Accuracy: 0.441600
# Epoch 33, CIFAR-10 Batch 4:  loss:   387.1978 Validation Accuracy: 0.434800
# Epoch 33, CIFAR-10 Batch 5:  loss:   330.8712 Validation Accuracy: 0.428000
# Epoch 34, CIFAR-10 Batch 1:  loss:   544.6600 Validation Accuracy: 0.423600
# Epoch 34, CIFAR-10 Batch 2:  loss:   324.4438 Validation Accuracy: 0.397200
# Epoch 34, CIFAR-10 Batch 3:  loss:   155.7078 Validation Accuracy: 0.431800
# Epoch 34, CIFAR-10 Batch 4:  loss:   283.8912 Validation Accuracy: 0.415000
# Epoch 34, CIFAR-10 Batch 5:  loss:   180.8923 Validation Accuracy: 0.413400
# Epoch 35, CIFAR-10 Batch 1:  loss:   369.6111 Validation Accuracy: 0.388400
# Epoch 35, CIFAR-10 Batch 2:  loss:   177.9226 Validation Accuracy: 0.355800
# Epoch 35, CIFAR-10 Batch 3:  loss:    45.5649 Validation Accuracy: 0.333400
# Epoch 35, CIFAR-10 Batch 4:  loss:   213.8285 Validation Accuracy: 0.326000
# Epoch 35, CIFAR-10 Batch 5:  loss:   100.7067 Validation Accuracy: 0.330200
# Epoch 36, CIFAR-10 Batch 1:  loss:   255.6677 Validation Accuracy: 0.335200
# Epoch 36, CIFAR-10 Batch 2:  loss:    85.3399 Validation Accuracy: 0.321400
# Epoch 36, CIFAR-10 Batch 3:  loss:    14.9585 Validation Accuracy: 0.340600
# Epoch 36, CIFAR-10 Batch 4:  loss:   148.0966 Validation Accuracy: 0.301200
# Epoch 36, CIFAR-10 Batch 5:  loss:    61.4356 Validation Accuracy: 0.332000
# Epoch 37, CIFAR-10 Batch 1:  loss:   147.4715 Validation Accuracy: 0.297400
# Epoch 37, CIFAR-10 Batch 2:  loss:    53.8761 Validation Accuracy: 0.292200
# Epoch 37, CIFAR-10 Batch 3:  loss:     6.1948 Validation Accuracy: 0.326600
# Epoch 37, CIFAR-10 Batch 4:  loss:    61.6522 Validation Accuracy: 0.311400
# Epoch 37, CIFAR-10 Batch 5:  loss:    25.1057 Validation Accuracy: 0.301800
# Epoch 38, CIFAR-10 Batch 1:  loss:    47.5995 Validation Accuracy: 0.303600
# Epoch 38, CIFAR-10 Batch 2:  loss:    15.5628 Validation Accuracy: 0.290400
# Epoch 38, CIFAR-10 Batch 3:  loss:     7.0420 Validation Accuracy: 0.323400
# Epoch 38, CIFAR-10 Batch 4:  loss:     7.2883 Validation Accuracy: 0.272400
# Epoch 38, CIFAR-10 Batch 5:  loss:     5.4096 Validation Accuracy: 0.266200
# Epoch 39, CIFAR-10 Batch 1:  loss:     7.4705 Validation Accuracy: 0.277400
# Epoch 39, CIFAR-10 Batch 2:  loss:     5.5875 Validation Accuracy: 0.280600
# Epoch 39, CIFAR-10 Batch 3:  loss:     7.1445 Validation Accuracy: 0.254200
# Epoch 39, CIFAR-10 Batch 4:  loss:     8.5463 Validation Accuracy: 0.277400
# Epoch 39, CIFAR-10 Batch 5:  loss:     3.8679 Validation Accuracy: 0.306200
# Epoch 40, CIFAR-10 Batch 1:  loss:     6.3414 Validation Accuracy: 0.271800
# Epoch 40, CIFAR-10 Batch 2:  loss:     3.9628 Validation Accuracy: 0.283200
# Epoch 40, CIFAR-10 Batch 3:  loss:     5.8082 Validation Accuracy: 0.303400
# Epoch 40, CIFAR-10 Batch 4:  loss:     4.5910 Validation Accuracy: 0.292400
# Epoch 40, CIFAR-10 Batch 5:  loss:     3.2200 Validation Accuracy: 0.280200
# Epoch 41, CIFAR-10 Batch 1:  loss:     5.6154 Validation Accuracy: 0.276200
# Epoch 41, CIFAR-10 Batch 2:  loss:     5.7231 Validation Accuracy: 0.238200
# Epoch 41, CIFAR-10 Batch 3:  loss:     7.8944 Validation Accuracy: 0.292600
# Epoch 41, CIFAR-10 Batch 4:  loss:     5.5702 Validation Accuracy: 0.305800
# Epoch 41, CIFAR-10 Batch 5:  loss:     4.2192 Validation Accuracy: 0.295400
# Epoch 42, CIFAR-10 Batch 1:  loss:     6.9467 Validation Accuracy: 0.269200
# Epoch 42, CIFAR-10 Batch 2:  loss:     8.2659 Validation Accuracy: 0.223800
# Epoch 42, CIFAR-10 Batch 3:  loss:     5.0758 Validation Accuracy: 0.300000
# Epoch 42, CIFAR-10 Batch 4:  loss:     5.3979 Validation Accuracy: 0.271600
# Epoch 42, CIFAR-10 Batch 5:  loss:     5.4259 Validation Accuracy: 0.281600
# Epoch 43, CIFAR-10 Batch 1:  loss:     4.0864 Validation Accuracy: 0.321000
# Epoch 43, CIFAR-10 Batch 2:  loss:     3.8461 Validation Accuracy: 0.262600
# Epoch 43, CIFAR-10 Batch 3:  loss:     5.3858 Validation Accuracy: 0.255200
# Epoch 43, CIFAR-10 Batch 4:  loss:     3.8624 Validation Accuracy: 0.311200
# Epoch 43, CIFAR-10 Batch 5:  loss:     4.2172 Validation Accuracy: 0.320200
# Epoch 44, CIFAR-10 Batch 1:  loss:     5.4052 Validation Accuracy: 0.274600
# Epoch 44, CIFAR-10 Batch 2:  loss:     4.9401 Validation Accuracy: 0.256800
# Epoch 44, CIFAR-10 Batch 3:  loss:     5.0867 Validation Accuracy: 0.290800
# Epoch 44, CIFAR-10 Batch 4:  loss:     4.5538 Validation Accuracy: 0.295600
# Epoch 44, CIFAR-10 Batch 5:  loss:     3.5753 Validation Accuracy: 0.275000
# Epoch 45, CIFAR-10 Batch 1:  loss:     5.5614 Validation Accuracy: 0.287000
# Epoch 45, CIFAR-10 Batch 2:  loss:     4.5588 Validation Accuracy: 0.259200
# Epoch 45, CIFAR-10 Batch 3:  loss:     5.5184 Validation Accuracy: 0.297200
# Epoch 45, CIFAR-10 Batch 4:  loss:     6.8313 Validation Accuracy: 0.287400
# Epoch 45, CIFAR-10 Batch 5:  loss:     3.7448 Validation Accuracy: 0.294000
# Epoch 46, CIFAR-10 Batch 1:  loss:     6.3680 Validation Accuracy: 0.330200
# Epoch 46, CIFAR-10 Batch 2:  loss:     5.2480 Validation Accuracy: 0.282800
# Epoch 46, CIFAR-10 Batch 3:  loss:     5.5807 Validation Accuracy: 0.292200
# Epoch 46, CIFAR-10 Batch 4:  loss:     5.3447 Validation Accuracy: 0.282200
# Epoch 46, CIFAR-10 Batch 5:  loss:     5.4731 Validation Accuracy: 0.303000
# Epoch 47, CIFAR-10 Batch 1:  loss:     3.5459 Validation Accuracy: 0.305000
# Epoch 47, CIFAR-10 Batch 2:  loss:     5.0638 Validation Accuracy: 0.248400
# Epoch 47, CIFAR-10 Batch 3:  loss:     5.0362 Validation Accuracy: 0.290400
# Epoch 47, CIFAR-10 Batch 4:  loss:     5.5426 Validation Accuracy: 0.302200
# Epoch 47, CIFAR-10 Batch 5:  loss:     5.4055 Validation Accuracy: 0.291000
# Epoch 48, CIFAR-10 Batch 1:  loss:     5.1974 Validation Accuracy: 0.256400
# Epoch 48, CIFAR-10 Batch 2:  loss:     4.8852 Validation Accuracy: 0.233800
# Epoch 48, CIFAR-10 Batch 3:  loss:     3.4375 Validation Accuracy: 0.279000
# Epoch 48, CIFAR-10 Batch 4:  loss:     5.2752 Validation Accuracy: 0.317800
# Epoch 48, CIFAR-10 Batch 5:  loss:     4.4265 Validation Accuracy: 0.302600
# Epoch 49, CIFAR-10 Batch 1:  loss:     5.8892 Validation Accuracy: 0.278000
# Epoch 49, CIFAR-10 Batch 2:  loss:     4.2425 Validation Accuracy: 0.288400
# Epoch 49, CIFAR-10 Batch 3:  loss:     4.9251 Validation Accuracy: 0.269800
# Epoch 49, CIFAR-10 Batch 4:  loss:     5.7031 Validation Accuracy: 0.286400
# Epoch 49, CIFAR-10 Batch 5:  loss:     5.4622 Validation Accuracy: 0.226000
# Epoch 50, CIFAR-10 Batch 1:  loss:     5.5407 Validation Accuracy: 0.285000
# Epoch 50, CIFAR-10 Batch 2:  loss:     5.1192 Validation Accuracy: 0.257800
# Epoch 50, CIFAR-10 Batch 3:  loss:     5.5192 Validation Accuracy: 0.277600
# Epoch 50, CIFAR-10 Batch 4:  loss:     5.5053 Validation Accuracy: 0.297000
# Epoch 50, CIFAR-10 Batch 5:  loss:     3.9674 Validation Accuracy: 0.264600
# Epoch 51, CIFAR-10 Batch 1:  loss:     7.3886 Validation Accuracy: 0.270800
# Epoch 51, CIFAR-10 Batch 2:  loss:     4.0760 Validation Accuracy: 0.247200
# Epoch 51, CIFAR-10 Batch 3:  loss:     4.8691 Validation Accuracy: 0.281200
# Epoch 51, CIFAR-10 Batch 4:  loss:     4.8783 Validation Accuracy: 0.289800
# Epoch 51, CIFAR-10 Batch 5:  loss:     4.1601 Validation Accuracy: 0.293400
# Epoch 52, CIFAR-10 Batch 1:  loss:     5.7368 Validation Accuracy: 0.258000
# Epoch 52, CIFAR-10 Batch 2:  loss:     4.2332 Validation Accuracy: 0.224000
# Epoch 52, CIFAR-10 Batch 3:  loss:     4.0606 Validation Accuracy: 0.235600
# Epoch 52, CIFAR-10 Batch 4:  loss:     3.0074 Validation Accuracy: 0.288000
# Epoch 52, CIFAR-10 Batch 5:  loss:     4.7573 Validation Accuracy: 0.240200
# Epoch 53, CIFAR-10 Batch 1:  loss:     6.2844 Validation Accuracy: 0.265000
# Epoch 53, CIFAR-10 Batch 2:  loss:     4.6443 Validation Accuracy: 0.249800
# Epoch 53, CIFAR-10 Batch 3:  loss:     4.4364 Validation Accuracy: 0.291400
# Epoch 53, CIFAR-10 Batch 4:  loss:     5.0400 Validation Accuracy: 0.273000
# Epoch 53, CIFAR-10 Batch 5:  loss:     4.5159 Validation Accuracy: 0.282800
# Epoch 54, CIFAR-10 Batch 1:  loss:     5.5485 Validation Accuracy: 0.256600
# Epoch 54, CIFAR-10 Batch 2:  loss:     3.7735 Validation Accuracy: 0.229600
# Epoch 54, CIFAR-10 Batch 3:  loss:     4.4932 Validation Accuracy: 0.251200
# Epoch 54, CIFAR-10 Batch 4:  loss:     4.6463 Validation Accuracy: 0.292800
# Epoch 54, CIFAR-10 Batch 5:  loss:     3.4805 Validation Accuracy: 0.253600
# Epoch 55, CIFAR-10 Batch 1:  loss:     5.8183 Validation Accuracy: 0.257800
# Epoch 55, CIFAR-10 Batch 2:  loss:     4.7559 Validation Accuracy: 0.246000
# Epoch 55, CIFAR-10 Batch 3:  loss:     4.9285 Validation Accuracy: 0.236800
# Epoch 55, CIFAR-10 Batch 4:  loss:     4.5538 Validation Accuracy: 0.253800
# Epoch 55, CIFAR-10 Batch 5:  loss:     5.3444 Validation Accuracy: 0.231200
# Epoch 56, CIFAR-10 Batch 1:  loss:     3.3440 Validation Accuracy: 0.259800
# Epoch 56, CIFAR-10 Batch 2:  loss:     3.6848 Validation Accuracy: 0.257600
# Epoch 56, CIFAR-10 Batch 3:  loss:     3.8464 Validation Accuracy: 0.277400
# Epoch 56, CIFAR-10 Batch 4:  loss:     4.8156 Validation Accuracy: 0.291200
# Epoch 56, CIFAR-10 Batch 5:  loss:     3.5942 Validation Accuracy: 0.248400
# Epoch 57, CIFAR-10 Batch 1:  loss:     4.1926 Validation Accuracy: 0.246600
# Epoch 57, CIFAR-10 Batch 2:  loss:     3.6609 Validation Accuracy: 0.236400
# Epoch 57, CIFAR-10 Batch 3:  loss:     4.0445 Validation Accuracy: 0.205800
# Epoch 57, CIFAR-10 Batch 4:  loss:     3.8874 Validation Accuracy: 0.240000
# Epoch 57, CIFAR-10 Batch 5:  loss:     3.6215 Validation Accuracy: 0.241000
# Epoch 58, CIFAR-10 Batch 1:  loss:     4.3377 Validation Accuracy: 0.214400
# Epoch 58, CIFAR-10 Batch 2:  loss:     2.6123 Validation Accuracy: 0.246600
# Epoch 58, CIFAR-10 Batch 3:  loss:     4.6978 Validation Accuracy: 0.222600
# Epoch 58, CIFAR-10 Batch 4:  loss:     4.0455 Validation Accuracy: 0.251200
# Epoch 58, CIFAR-10 Batch 5:  loss:     5.0360 Validation Accuracy: 0.201800
# Epoch 59, CIFAR-10 Batch 1:  loss:     3.7425 Validation Accuracy: 0.201800
# Epoch 59, CIFAR-10 Batch 2:  loss:     4.3017 Validation Accuracy: 0.208200
# Epoch 59, CIFAR-10 Batch 3:  loss:     4.8061 Validation Accuracy: 0.190200
# Epoch 59, CIFAR-10 Batch 4:  loss:     3.1827 Validation Accuracy: 0.251200
# Epoch 59, CIFAR-10 Batch 5:  loss:     4.3356 Validation Accuracy: 0.212800
# Epoch 60, CIFAR-10 Batch 1:  loss:     3.0415 Validation Accuracy: 0.238600
# Epoch 60, CIFAR-10 Batch 2:  loss:     4.0925 Validation Accuracy: 0.184000
# Epoch 60, CIFAR-10 Batch 3:  loss:     3.6948 Validation Accuracy: 0.245600
# Epoch 60, CIFAR-10 Batch 4:  loss:     3.4474 Validation Accuracy: 0.232400
# Epoch 60, CIFAR-10 Batch 5:  loss:     2.7093 Validation Accuracy: 0.239400
# Epoch 61, CIFAR-10 Batch 1:  loss:     4.0842 Validation Accuracy: 0.220800
# Epoch 61, CIFAR-10 Batch 2:  loss:     3.3649 Validation Accuracy: 0.199200
# Epoch 61, CIFAR-10 Batch 3:  loss:     3.1692 Validation Accuracy: 0.204800
# Epoch 61, CIFAR-10 Batch 4:  loss:     2.6328 Validation Accuracy: 0.221000
# Epoch 61, CIFAR-10 Batch 5:  loss:     4.0891 Validation Accuracy: 0.199000
# Epoch 62, CIFAR-10 Batch 1:  loss:     2.6909 Validation Accuracy: 0.201000
# Epoch 62, CIFAR-10 Batch 2:  loss:     3.0883 Validation Accuracy: 0.217800
# Epoch 62, CIFAR-10 Batch 3:  loss:     3.5095 Validation Accuracy: 0.198600
# Epoch 62, CIFAR-10 Batch 4:  loss:     3.4445 Validation Accuracy: 0.203200
# Epoch 62, CIFAR-10 Batch 5:  loss:     4.0909 Validation Accuracy: 0.207200
# Epoch 63, CIFAR-10 Batch 1:  loss:     3.3357 Validation Accuracy: 0.214000
# Epoch 63, CIFAR-10 Batch 2:  loss:     2.8088 Validation Accuracy: 0.187800
# Epoch 63, CIFAR-10 Batch 3:  loss:     2.9696 Validation Accuracy: 0.167600
# Epoch 63, CIFAR-10 Batch 4:  loss:     2.9715 Validation Accuracy: 0.234800
# Epoch 63, CIFAR-10 Batch 5:  loss:     2.8122 Validation Accuracy: 0.199000
# Epoch 64, CIFAR-10 Batch 1:  loss:     2.7999 Validation Accuracy: 0.201800
# Epoch 64, CIFAR-10 Batch 2:  loss:     2.5975 Validation Accuracy: 0.180400
# Epoch 64, CIFAR-10 Batch 3:  loss:     2.6914 Validation Accuracy: 0.201800
# Epoch 64, CIFAR-10 Batch 4:  loss:     2.7458 Validation Accuracy: 0.198400
# Epoch 64, CIFAR-10 Batch 5:  loss:     3.5228 Validation Accuracy: 0.166400
# Epoch 65, CIFAR-10 Batch 1:  loss:     3.0274 Validation Accuracy: 0.191600
# Epoch 65, CIFAR-10 Batch 2:  loss:     2.5931 Validation Accuracy: 0.155600
# Epoch 65, CIFAR-10 Batch 3:  loss:     3.1074 Validation Accuracy: 0.156200
# Epoch 65, CIFAR-10 Batch 4:  loss:     2.5597 Validation Accuracy: 0.201000
# Epoch 65, CIFAR-10 Batch 5:  loss:     3.4669 Validation Accuracy: 0.189600
# Epoch 66, CIFAR-10 Batch 1:  loss:     2.5388 Validation Accuracy: 0.184600
# Epoch 66, CIFAR-10 Batch 2:  loss:     3.4297 Validation Accuracy: 0.162400
# Epoch 66, CIFAR-10 Batch 3:  loss:     2.4751 Validation Accuracy: 0.189800
# Epoch 66, CIFAR-10 Batch 4:  loss:     2.4093 Validation Accuracy: 0.202600
# Epoch 66, CIFAR-10 Batch 5:  loss:     2.9060 Validation Accuracy: 0.187000
# Epoch 67, CIFAR-10 Batch 1:  loss:     2.4133 Validation Accuracy: 0.207600
# Epoch 67, CIFAR-10 Batch 2:  loss:     2.6341 Validation Accuracy: 0.144800
# Epoch 67, CIFAR-10 Batch 3:  loss:     2.2329 Validation Accuracy: 0.191200
# Epoch 67, CIFAR-10 Batch 4:  loss:     2.2680 Validation Accuracy: 0.181200
# Epoch 67, CIFAR-10 Batch 5:  loss:     2.7867 Validation Accuracy: 0.201600
# Epoch 68, CIFAR-10 Batch 1:  loss:     2.5023 Validation Accuracy: 0.186400
# Epoch 68, CIFAR-10 Batch 2:  loss:     2.1631 Validation Accuracy: 0.190400
# Epoch 68, CIFAR-10 Batch 3:  loss:     2.2491 Validation Accuracy: 0.193400
# Epoch 68, CIFAR-10 Batch 4:  loss:     1.9949 Validation Accuracy: 0.196200
# Epoch 68, CIFAR-10 Batch 5:  loss:     2.8103 Validation Accuracy: 0.176600
# Epoch 69, CIFAR-10 Batch 1:  loss:     1.9997 Validation Accuracy: 0.197000
# Epoch 69, CIFAR-10 Batch 2:  loss:     2.1881 Validation Accuracy: 0.167400
# Epoch 69, CIFAR-10 Batch 3:  loss:     2.3726 Validation Accuracy: 0.177000
# Epoch 69, CIFAR-10 Batch 4:  loss:     2.2004 Validation Accuracy: 0.188800
# Epoch 69, CIFAR-10 Batch 5:  loss:     2.7278 Validation Accuracy: 0.175000
# Epoch 70, CIFAR-10 Batch 1:  loss:     2.7156 Validation Accuracy: 0.166200
# Epoch 70, CIFAR-10 Batch 2:  loss:     2.3368 Validation Accuracy: 0.171000
# Epoch 70, CIFAR-10 Batch 3:  loss:     2.3889 Validation Accuracy: 0.168200
# Epoch 70, CIFAR-10 Batch 4:  loss:     2.4986 Validation Accuracy: 0.192000
# Epoch 70, CIFAR-10 Batch 5:  loss:     2.7548 Validation Accuracy: 0.174200
# Epoch 71, CIFAR-10 Batch 1:  loss:     2.0794 Validation Accuracy: 0.188000
# Epoch 71, CIFAR-10 Batch 2:  loss:     1.9842 Validation Accuracy: 0.170400
# Epoch 71, CIFAR-10 Batch 3:  loss:     2.1548 Validation Accuracy: 0.182600
# Epoch 71, CIFAR-10 Batch 4:  loss:     2.0428 Validation Accuracy: 0.187400
# Epoch 71, CIFAR-10 Batch 5:  loss:     2.6645 Validation Accuracy: 0.181000
# Epoch 72, CIFAR-10 Batch 1:  loss:     2.6382 Validation Accuracy: 0.149200
# Epoch 72, CIFAR-10 Batch 2:  loss:     2.4038 Validation Accuracy: 0.175000
# Epoch 72, CIFAR-10 Batch 3:  loss:     1.9220 Validation Accuracy: 0.192400
# Epoch 72, CIFAR-10 Batch 4:  loss:     2.0945 Validation Accuracy: 0.195600
# Epoch 72, CIFAR-10 Batch 5:  loss:     2.3850 Validation Accuracy: 0.187400
# Epoch 73, CIFAR-10 Batch 1:  loss:     2.2955 Validation Accuracy: 0.195400
# Epoch 73, CIFAR-10 Batch 2:  loss:     2.2600 Validation Accuracy: 0.164400
# Epoch 73, CIFAR-10 Batch 3:  loss:     1.9012 Validation Accuracy: 0.202000
# Epoch 73, CIFAR-10 Batch 4:  loss:     2.1650 Validation Accuracy: 0.188800
# Epoch 73, CIFAR-10 Batch 5:  loss:     2.3460 Validation Accuracy: 0.197800
# Epoch 74, CIFAR-10 Batch 1:  loss:     2.1972 Validation Accuracy: 0.181800
# Epoch 74, CIFAR-10 Batch 2:  loss:     2.0410 Validation Accuracy: 0.178400
# Epoch 74, CIFAR-10 Batch 3:  loss:     1.8760 Validation Accuracy: 0.203200
# Epoch 74, CIFAR-10 Batch 4:  loss:     2.1046 Validation Accuracy: 0.194800
# Epoch 74, CIFAR-10 Batch 5:  loss:     2.4143 Validation Accuracy: 0.197600
# Epoch 75, CIFAR-10 Batch 1:  loss:     2.1835 Validation Accuracy: 0.193000
# Epoch 75, CIFAR-10 Batch 2:  loss:     2.0605 Validation Accuracy: 0.173800
# Epoch 75, CIFAR-10 Batch 3:  loss:     2.0420 Validation Accuracy: 0.154800
# Epoch 75, CIFAR-10 Batch 4:  loss:     2.1423 Validation Accuracy: 0.217400
# Epoch 75, CIFAR-10 Batch 5:  loss:     2.1740 Validation Accuracy: 0.211200
# Epoch 76, CIFAR-10 Batch 1:  loss:     2.4729 Validation Accuracy: 0.187200
# Epoch 76, CIFAR-10 Batch 2:  loss:     2.0835 Validation Accuracy: 0.180000
# Epoch 76, CIFAR-10 Batch 3:  loss:     2.0623 Validation Accuracy: 0.175800
# Epoch 76, CIFAR-10 Batch 4:  loss:     2.1564 Validation Accuracy: 0.206800
# Epoch 76, CIFAR-10 Batch 5:  loss:     2.3749 Validation Accuracy: 0.175600
# Epoch 77, CIFAR-10 Batch 1:  loss:     2.2167 Validation Accuracy: 0.188400
# Epoch 77, CIFAR-10 Batch 2:  loss:     2.0737 Validation Accuracy: 0.182400
# Epoch 77, CIFAR-10 Batch 3:  loss:     2.1354 Validation Accuracy: 0.182400
# Epoch 77, CIFAR-10 Batch 4:  loss:     2.0616 Validation Accuracy: 0.196200
# Epoch 77, CIFAR-10 Batch 5:  loss:     2.2893 Validation Accuracy: 0.202600
# Epoch 78, CIFAR-10 Batch 1:  loss:     2.2309 Validation Accuracy: 0.206400
# Epoch 78, CIFAR-10 Batch 2:  loss:     1.9684 Validation Accuracy: 0.218000
# Epoch 78, CIFAR-10 Batch 3:  loss:     1.8101 Validation Accuracy: 0.221000
# Epoch 78, CIFAR-10 Batch 4:  loss:     2.0512 Validation Accuracy: 0.204400
# Epoch 78, CIFAR-10 Batch 5:  loss:     2.2935 Validation Accuracy: 0.193400
# Epoch 79, CIFAR-10 Batch 1:  loss:     2.5467 Validation Accuracy: 0.206200
# Epoch 79, CIFAR-10 Batch 2:  loss:     2.1512 Validation Accuracy: 0.177400
# Epoch 79, CIFAR-10 Batch 3:  loss:     2.0694 Validation Accuracy: 0.205600
# Epoch 79, CIFAR-10 Batch 4:  loss:     2.0533 Validation Accuracy: 0.216400
# Epoch 79, CIFAR-10 Batch 5:  loss:     2.2002 Validation Accuracy: 0.209000
# Epoch 80, CIFAR-10 Batch 1:  loss:     2.2446 Validation Accuracy: 0.204400
# Epoch 80, CIFAR-10 Batch 2:  loss:     1.9912 Validation Accuracy: 0.199000
# Epoch 80, CIFAR-10 Batch 3:  loss:     1.9881 Validation Accuracy: 0.239600
# Epoch 80, CIFAR-10 Batch 4:  loss:     2.0880 Validation Accuracy: 0.194400
# Epoch 80, CIFAR-10 Batch 5:  loss:     2.2380 Validation Accuracy: 0.219400
# Epoch 81, CIFAR-10 Batch 1:  loss:     2.0938 Validation Accuracy: 0.232200
# Epoch 81, CIFAR-10 Batch 2:  loss:     2.0205 Validation Accuracy: 0.216000
# Epoch 81, CIFAR-10 Batch 3:  loss:     1.9409 Validation Accuracy: 0.239000
# Epoch 81, CIFAR-10 Batch 4:  loss:     2.1238 Validation Accuracy: 0.220600
# Epoch 81, CIFAR-10 Batch 5:  loss:     2.1303 Validation Accuracy: 0.221600
# Epoch 82, CIFAR-10 Batch 1:  loss:     2.3567 Validation Accuracy: 0.231800
# Epoch 82, CIFAR-10 Batch 2:  loss:     2.0909 Validation Accuracy: 0.224400
# Epoch 82, CIFAR-10 Batch 3:  loss:     1.9409 Validation Accuracy: 0.230200
# Epoch 82, CIFAR-10 Batch 4:  loss:     2.0029 Validation Accuracy: 0.220400
# Epoch 82, CIFAR-10 Batch 5:  loss:     2.2056 Validation Accuracy: 0.207800
# Epoch 83, CIFAR-10 Batch 1:  loss:     2.4603 Validation Accuracy: 0.235200
# Epoch 83, CIFAR-10 Batch 2:  loss:     2.0396 Validation Accuracy: 0.219400
# Epoch 83, CIFAR-10 Batch 3:  loss:     1.9799 Validation Accuracy: 0.226000
# Epoch 83, CIFAR-10 Batch 4:  loss:     2.0564 Validation Accuracy: 0.237200
# Epoch 83, CIFAR-10 Batch 5:  loss:     2.0327 Validation Accuracy: 0.219200
# Epoch 84, CIFAR-10 Batch 1:  loss:     2.2417 Validation Accuracy: 0.205200
# Epoch 84, CIFAR-10 Batch 2:  loss:     2.1296 Validation Accuracy: 0.223000
# Epoch 84, CIFAR-10 Batch 3:  loss:     2.0179 Validation Accuracy: 0.248000
# Epoch 84, CIFAR-10 Batch 4:  loss:     2.0723 Validation Accuracy: 0.233600
# Epoch 84, CIFAR-10 Batch 5:  loss:     2.0947 Validation Accuracy: 0.229200
# Epoch 85, CIFAR-10 Batch 1:  loss:     2.5719 Validation Accuracy: 0.210400
# Epoch 85, CIFAR-10 Batch 2:  loss:     2.0367 Validation Accuracy: 0.216000
# Epoch 85, CIFAR-10 Batch 3:  loss:     2.0306 Validation Accuracy: 0.213600
# Epoch 85, CIFAR-10 Batch 4:  loss:     2.0757 Validation Accuracy: 0.225400
# Epoch 85, CIFAR-10 Batch 5:  loss:     2.0308 Validation Accuracy: 0.236200
# Epoch 86, CIFAR-10 Batch 1:  loss:     2.5884 Validation Accuracy: 0.195000
# Epoch 86, CIFAR-10 Batch 2:  loss:     2.0411 Validation Accuracy: 0.244200
# Epoch 86, CIFAR-10 Batch 3:  loss:     1.9817 Validation Accuracy: 0.229400
# Epoch 86, CIFAR-10 Batch 4:  loss:     2.0464 Validation Accuracy: 0.219200
# Epoch 86, CIFAR-10 Batch 5:  loss:     2.0958 Validation Accuracy: 0.229200
# Epoch 87, CIFAR-10 Batch 1:  loss:     2.1813 Validation Accuracy: 0.222800
# Epoch 87, CIFAR-10 Batch 2:  loss:     2.0150 Validation Accuracy: 0.243600
# Epoch 87, CIFAR-10 Batch 3:  loss:     1.8931 Validation Accuracy: 0.247400
# Epoch 87, CIFAR-10 Batch 4:  loss:     2.0618 Validation Accuracy: 0.237200
# Epoch 87, CIFAR-10 Batch 5:  loss:     2.0911 Validation Accuracy: 0.237000
# Epoch 88, CIFAR-10 Batch 1:  loss:     2.1542 Validation Accuracy: 0.232000
# Epoch 88, CIFAR-10 Batch 2:  loss:     2.0129 Validation Accuracy: 0.236200
# Epoch 88, CIFAR-10 Batch 3:  loss:     1.9993 Validation Accuracy: 0.237600
# Epoch 88, CIFAR-10 Batch 4:  loss:     2.0501 Validation Accuracy: 0.231000
# Epoch 88, CIFAR-10 Batch 5:  loss:     2.0595 Validation Accuracy: 0.240000
# Epoch 89, CIFAR-10 Batch 1:  loss:     2.7342 Validation Accuracy: 0.184000
# Epoch 89, CIFAR-10 Batch 2:  loss:     2.0370 Validation Accuracy: 0.245200
# Epoch 89, CIFAR-10 Batch 3:  loss:     1.9905 Validation Accuracy: 0.248600
# Epoch 89, CIFAR-10 Batch 4:  loss:     2.0043 Validation Accuracy: 0.244800
# Epoch 89, CIFAR-10 Batch 5:  loss:     2.0341 Validation Accuracy: 0.225800
# Epoch 90, CIFAR-10 Batch 1:  loss:     2.3656 Validation Accuracy: 0.219400
# Epoch 90, CIFAR-10 Batch 2:  loss:     2.0551 Validation Accuracy: 0.257200
# Epoch 90, CIFAR-10 Batch 3:  loss:     2.0057 Validation Accuracy: 0.229200
# Epoch 90, CIFAR-10 Batch 4:  loss:     2.0859 Validation Accuracy: 0.229600
# Epoch 90, CIFAR-10 Batch 5:  loss:     2.0305 Validation Accuracy: 0.258600
# Epoch 91, CIFAR-10 Batch 1:  loss:     2.2723 Validation Accuracy: 0.237800
# Epoch 91, CIFAR-10 Batch 2:  loss:     2.0128 Validation Accuracy: 0.247000
# Epoch 91, CIFAR-10 Batch 3:  loss:     1.9462 Validation Accuracy: 0.254600
# Epoch 91, CIFAR-10 Batch 4:  loss:     2.0586 Validation Accuracy: 0.242000
# Epoch 91, CIFAR-10 Batch 5:  loss:     2.0008 Validation Accuracy: 0.252000
# Epoch 92, CIFAR-10 Batch 1:  loss:     2.2456 Validation Accuracy: 0.184600
# Epoch 92, CIFAR-10 Batch 2:  loss:     2.0128 Validation Accuracy: 0.229400
# Epoch 92, CIFAR-10 Batch 3:  loss:     1.9821 Validation Accuracy: 0.246600
# Epoch 92, CIFAR-10 Batch 4:  loss:     2.0609 Validation Accuracy: 0.240800
# Epoch 92, CIFAR-10 Batch 5:  loss:     1.9755 Validation Accuracy: 0.249000
# Epoch 93, CIFAR-10 Batch 1:  loss:     2.2099 Validation Accuracy: 0.225400
# Epoch 93, CIFAR-10 Batch 2:  loss:     2.0000 Validation Accuracy: 0.255000
# Epoch 93, CIFAR-10 Batch 3:  loss:     1.9545 Validation Accuracy: 0.243000
# Epoch 93, CIFAR-10 Batch 4:  loss:     2.0323 Validation Accuracy: 0.251800
# Epoch 93, CIFAR-10 Batch 5:  loss:     2.0025 Validation Accuracy: 0.247200
# Epoch 94, CIFAR-10 Batch 1:  loss:     2.1726 Validation Accuracy: 0.210000
# Epoch 94, CIFAR-10 Batch 2:  loss:     2.0262 Validation Accuracy: 0.247000
# Epoch 94, CIFAR-10 Batch 3:  loss:     1.9130 Validation Accuracy: 0.259400
# Epoch 94, CIFAR-10 Batch 4:  loss:     2.0494 Validation Accuracy: 0.255200
# Epoch 94, CIFAR-10 Batch 5:  loss:     1.9798 Validation Accuracy: 0.260600
# Epoch 95, CIFAR-10 Batch 1:  loss:     2.1028 Validation Accuracy: 0.265400
# Epoch 95, CIFAR-10 Batch 2:  loss:     2.1925 Validation Accuracy: 0.167400
# Epoch 95, CIFAR-10 Batch 3:  loss:     2.2550 Validation Accuracy: 0.145800
# Epoch 95, CIFAR-10 Batch 4:  loss:     2.9040 Validation Accuracy: 0.163400
# Epoch 95, CIFAR-10 Batch 5:  loss:     2.2634 Validation Accuracy: 0.160200
# Epoch 96, CIFAR-10 Batch 1:  loss:     2.2853 Validation Accuracy: 0.143200
# Epoch 96, CIFAR-10 Batch 2:  loss:     2.2104 Validation Accuracy: 0.149400
# Epoch 96, CIFAR-10 Batch 3:  loss:     2.2442 Validation Accuracy: 0.140800
# Epoch 96, CIFAR-10 Batch 4:  loss:     2.3156 Validation Accuracy: 0.154600
# Epoch 96, CIFAR-10 Batch 5:  loss:     2.2635 Validation Accuracy: 0.140000
# Epoch 97, CIFAR-10 Batch 1:  loss:     2.2911 Validation Accuracy: 0.155400
# Epoch 97, CIFAR-10 Batch 2:  loss:     2.2351 Validation Accuracy: 0.156800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-390-9df3032ebe9d> in <module>()
#      15         for batch_i in range(1, n_batches + 1):
#      16             for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 17                 train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      18             print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
#      19             print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-386-65e09a470b51> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#      19             x: feature_batch,
#      20             y: label_batch,
# ---> 21             keep_prob: keep_probability})
#      22
#      23     pass
#
# //anaconda/envs/tflearn/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# //anaconda/envs/tflearn/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# //anaconda/envs/tflearn/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# //anaconda/envs/tflearn/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# //anaconda/envs/tflearn/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
